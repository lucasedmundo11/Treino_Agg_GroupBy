# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# ___

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ____

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc = pd.read_csv('SINASC_RO_2019.csv')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %% [markdown]
# ____

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade média das mães e dos pais por município (coluna munResNome)

# %%
sinasc[['munResNome', 'IDADEMAE', 'IDADEPAI']].groupby('munResNome').mean()
# Out:
#                             IDADEMAE   IDADEPAI
# munResNome
# Alta Floresta D'Oeste      25.991826  29.548701
# Alto Alegre dos Parecis    24.844156  29.179104
# Alto Paraíso               24.960177  28.833333
# Alvorada D'Oeste           25.770732  30.757282
# Ariquemes                  25.607866  32.466667
# Buritis                    25.559177  30.812500
# Cabixi                     26.037500  34.333333
# Cacaulândia                25.546667  36.333333
# Cacoal                     26.890102  30.931854
# Campo Novo de Rondônia     24.825301  30.500000
# Candeias do Jamari         25.243323  29.894737
# Castanheiras               27.281250  30.392857
# Cerejeiras                 27.240506  31.652778
# Chupinguaia                25.333333  29.629630
# Colorado do Oeste          27.602804  34.354839
# Corumbiara                 24.716535  32.470588
# Costa Marques              24.412017  30.613636
# Cujubim                    24.482927  31.400000
# Espigão D'Oeste            26.093333  31.198113
# Governador Jorge Teixeira  24.401786  29.222222
# Guajará-Mirim              25.462228  30.470588
# Itapuã do Oeste            26.064220  42.500000
# Jaru                       25.982974  32.197183
# Ji-Paraná                  26.361137  31.132239
# Machadinho D'Oeste         25.480000  31.326923
# Ministro Andreazza         27.904762  33.849315
# Mirante da Serra           26.304878  32.154762
# Monte Negro                25.648241  34.678571
# Município ignorado - RO    24.000000  22.000000
# Nova Brasilândia D'Oeste   26.222222  30.520833
# Nova Mamoré                25.326389  31.692308
# Nova União                 26.894231  31.371429
# Novo Horizonte do Oeste    26.938776  31.588235
# Ouro Preto do Oeste        26.375594  31.233244
# Parecis                    26.454545  32.473684
# Pimenta Bueno              25.199675  29.745174
# Pimenteiras do Oeste       25.075000  35.600000
# Porto Velho                26.312670  32.352679
# Presidente Médici          25.796053  30.150754
# Primavera de Rondônia      27.023256  31.888889
# Rio Crespo                 26.660000  28.000000
# Rolim de Moura             26.600863  30.360479
# Santa Luzia D'Oeste        26.121212  30.703297
# Seringueiras               24.910714  30.500000
# São Felipe D'Oeste         26.481481  31.395833
# São Francisco do Guaporé   25.660066  31.638889
# São Miguel do Guaporé      25.926346  32.666667
# Teixeirópolis              26.031250  31.500000
# Theobroma                  25.536082  30.083333
# Urupá                      26.688235  31.008929
# Vale do Anari              26.096774  34.000000
# Vale do Paraíso            25.679012  29.976744
# Vilhena                    26.433962  34.152941

# %% [markdown]
# ### 2. Peso médio dos bebês por sexo que nasceram no dia do seu aniversário por faixas de escolaridade da mãe
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc.loc[:,'DTNASC'] = pd.to_datetime(sinasc['DTNASC'])

# %%
sinasc.set_index('DTNASC', inplace=True)

# %%
sinasc.loc[(sinasc.index.day == 1) & (sinasc.index.month == 7)].pivot_table(values = 'PESO',index = ['ESCMAE', 'SEXO'])
# Out:
#                                   PESO
# ESCMAE          SEXO
# 1 a 3 anos      Masculino  2600.000000
# 12 anos ou mais Feminino   3470.000000
#                 Masculino  3333.750000
# 4 a 7 anos      Feminino   3091.250000
#                 Masculino  3188.750000
# 8 a 11 anos     Feminino   3201.769231
#                 Masculino  3401.000000
# Nenhuma         Feminino   3020.000000

# %% [markdown]
# ### 3. Qual o município que nasceram menos bebês em 2019?
#     - qual a idade média, máxima, mínima das mães e dos pais nesse município?

# %%
sinasc.loc[sinasc.index.year == 2019].groupby('munResNome')['IDADEMAE'].count().sort_values().head()
# Out:
# munResNome
# Município ignorado - RO     1
# Castanheiras               32
# Pimenteiras do Oeste       40
# Primavera de Rondônia      43
# Parecis                    44
# Name: IDADEMAE, dtype: int64

# %%
sinasc_agr = sinasc.loc[sinasc.munResNome == 'Castanheiras'].groupby('munResNome')[['IDADEMAE', 'IDADEPAI']]
sinasc_agr.agg([('média', 'mean'), ('mínimo', min), ('máximo', max)])
# Out:
#               IDADEMAE                 IDADEPAI
#                  média mínimo máximo      média mínimo máximo
# munResNome
# Castanheiras  27.28125     17     39  30.392857   17.0   43.0

# %% [markdown]
# ### 4. Qual o município que nasceram mais bebês no mês de março?
#     - qual a quantidade de filhos vivos média, máxima e mínima nesse município?
#     - qual a idade média, máxima e mínima dos pais nesse município?

# %%
sinasc.loc[sinasc.index.month == 3].groupby('munResNome')['IDADEMAE'].count().sort_values(ascending=False).head()
# Out:
# munResNome
# Porto Velho    744
# Ji-Paraná      188
# Vilhena        148
# Ariquemes      141
# Cacoal         133
# Name: IDADEMAE, dtype: int64

# %%
sinasc_agr = sinasc.loc[sinasc.munResNome == 'Porto Velho'].groupby('munResNome')['QTDFILVIVO']
sinasc_agr.agg([('média', 'mean'), ('máximo', max), ('mínimo', min)])
# Out:
#                 média  máximo  mínimo
# munResNome
# Porto Velho  1.167236    12.0     0.0

# %%
sinasc_agr = sinasc.loc[sinasc.munResNome == 'Porto Velho'].groupby('munResNome')[['IDADEMAE', 'IDADEPAI']]
sinasc_agr.agg([('média', 'mean'), ('máximo', max), ('mínimo', min)])
# Out:
#              IDADEMAE                 IDADEPAI
#                 média máximo mínimo      média máximo mínimo
# munResNome
# Porto Velho  26.31267     47     12  32.352679   65.0   16.0

# %%
sinasc['QTDFILVIVO'].value_counts()
# Out:
# 1.0     9390
# 0.0     9326
# 2.0     4474
# 3.0     1370
# 4.0      484
# 5.0      214
# 6.0      112
# 7.0       42
# 8.0       23
# 9.0        8
# 10.0       6
# 12.0       3
# 11.0       1
# 30.0       1
# 14.0       1
# Name: QTDFILVIVO, dtype: int64

# %%
sinasc_agr = sinasc.groupby('munResNome')['QTDFILVIVO']
sinasc_agr.agg([('média', 'mean'), ('máximo', max), ('mínimo', min)])
# Out:
#                               média  máximo  mínimo
# munResNome
# Alta Floresta D'Oeste      0.856354     7.0     0.0
# Alto Alegre dos Parecis    0.907895     5.0     0.0
# Alto Paraíso               1.162896     6.0     0.0
# Alvorada D'Oeste           0.975248     9.0     0.0
# Ariquemes                  0.962253     8.0     0.0
# Buritis                    1.353846    10.0     0.0
# Cabixi                     0.762500     4.0     0.0
# Cacaulândia                1.013333     7.0     0.0
# Cacoal                     0.899123     7.0     0.0
# Campo Novo de Rondônia     1.160305     5.0     0.0
# Candeias do Jamari         1.433775     8.0     0.0
# Castanheiras               1.062500     6.0     0.0
# Cerejeiras                 0.987124     8.0     0.0
# Chupinguaia                1.081250     8.0     0.0
# Colorado do Oeste          0.934579     8.0     0.0
# Corumbiara                 0.849206     4.0     0.0
# Costa Marques              1.258772    14.0     0.0
# Cujubim                    1.256158     7.0     0.0
# Espigão D'Oeste            1.405830    12.0     0.0
# Governador Jorge Teixeira  0.768519     5.0     0.0
# Guajará-Mirim              1.543563    11.0     0.0
# Itapuã do Oeste            1.410000     6.0     0.0
# Jaru                       0.891304     7.0     0.0
# Ji-Paraná                  0.933272     8.0     0.0
# Machadinho D'Oeste         1.114286    10.0     0.0
# Ministro Andreazza         1.095238     6.0     0.0
# Mirante da Serra           0.932515     5.0     0.0
# Monte Negro                0.989583     7.0     0.0
# Município ignorado - RO    1.000000     1.0     1.0
# Nova Brasilândia D'Oeste   0.879845     4.0     0.0
# Nova Mamoré                1.295455     8.0     0.0
# Nova União                 0.844660     4.0     0.0
# Novo Horizonte do Oeste    0.835052     4.0     0.0
# Ouro Preto do Oeste        0.899361     6.0     0.0
# Parecis                    1.302326     5.0     0.0
# Pimenta Bueno              0.863934     9.0     0.0
# Pimenteiras do Oeste       1.150000     5.0     0.0
# Porto Velho                1.167236    12.0     0.0
# Presidente Médici          0.930233     7.0     0.0
# Primavera de Rondônia      1.093023     4.0     0.0
# Rio Crespo                 1.255319     4.0     0.0
# Rolim de Moura             0.858542     5.0     0.0
# Santa Luzia D'Oeste        1.171717    30.0     0.0
# Seringueiras               0.880240     5.0     0.0
# São Felipe D'Oeste         0.773585     5.0     0.0
# São Francisco do Guaporé   1.079734     6.0     0.0
# São Miguel do Guaporé      0.891117     6.0     0.0
# Teixeirópolis              0.859375     6.0     0.0
# Theobroma                  0.905263     4.0     0.0
# Urupá                      0.946746     5.0     0.0
# Vale do Anari              1.173913     8.0     0.0
# Vale do Paraíso            0.696203     4.0     0.0
# Vilhena                    0.917929    10.0     0.0

# %%
sinasc_agr = sinasc.groupby('munResNome')[['IDADEMAE', 'IDADEPAI']]
sinasc_agr.agg([('média', 'mean'), ('máximo', max), ('mínimo', min)])
# Out:
#                             IDADEMAE                 IDADEPAI
#                                média máximo mínimo      média máximo mínimo
# munResNome
# Alta Floresta D'Oeste      25.991826     53     14  29.548701   58.0   17.0
# Alto Alegre dos Parecis    24.844156     41     14  29.179104   50.0   16.0
# Alto Paraíso               24.960177     42     11  28.833333   49.0   21.0
# Alvorada D'Oeste           25.770732     44     15  30.757282   52.0   17.0
# Ariquemes                  25.607866     44     13  32.466667   51.0   20.0
# Buritis                    25.559177     44     14  30.812500   49.0   18.0
# Cabixi                     26.037500     39     13  34.333333   47.0   19.0
# Cacaulândia                25.546667     42     16  36.333333   50.0   28.0
# Cacoal                     26.890102     47     14  30.931854   66.0   17.0
# Campo Novo de Rondônia     24.825301     40     13  30.500000   40.0   21.0
# Candeias do Jamari         25.243323     45     14  29.894737   41.0   21.0
# Castanheiras               27.281250     39     17  30.392857   43.0   17.0
# Cerejeiras                 27.240506     53     15  31.652778   52.0   19.0
# Chupinguaia                25.333333     42     13  29.629630   46.0   20.0
# Colorado do Oeste          27.602804     47     15  34.354839   53.0   23.0
# Corumbiara                 24.716535     43     15  32.470588   52.0   21.0
# Costa Marques              24.412017     41     12  30.613636   60.0   17.0
# Cujubim                    24.482927     42     14  31.400000   44.0   19.0
# Espigão D'Oeste            26.093333     44     14  31.198113   86.0   16.0
# Governador Jorge Teixeira  24.401786     41     13  29.222222   37.0   22.0
# Guajará-Mirim              25.462228     43     13  30.470588   44.0   19.0
# Itapuã do Oeste            26.064220     46     15  42.500000   73.0   25.0
# Jaru                       25.982974     45     12  32.197183   62.0   19.0
# Ji-Paraná                  26.361137     44     12  31.132239   63.0   15.0
# Machadinho D'Oeste         25.480000     44     13  31.326923   53.0   17.0
# Ministro Andreazza         27.904762     44     17  33.849315   55.0   21.0
# Mirante da Serra           26.304878     46     14  32.154762   56.0   20.0
# Monte Negro                25.648241     40     14  34.678571   55.0   20.0
# Município ignorado - RO    24.000000     24     24  22.000000   22.0   22.0
# Nova Brasilândia D'Oeste   26.222222     51     15  30.520833   48.0   20.0
# Nova Mamoré                25.326389     46     14  31.692308   43.0   19.0
# Nova União                 26.894231     39     16  31.371429   53.0   18.0
# Novo Horizonte do Oeste    26.938776     41     15  31.588235   56.0   20.0
# Ouro Preto do Oeste        26.375594     44     14  31.233244   60.0   17.0
# Parecis                    26.454545     41     16  32.473684   61.0   18.0
# Pimenta Bueno              25.199675     47     13  29.745174   70.0   16.0
# Pimenteiras do Oeste       25.075000     40     14  35.600000   45.0   25.0
# Porto Velho                26.312670     47     12  32.352679   65.0   16.0
# Presidente Médici          25.796053     44     14  30.150754   64.0   16.0
# Primavera de Rondônia      27.023256     39     16  31.888889   44.0   21.0
# Rio Crespo                 26.660000     39     16  28.000000   28.0   28.0
# Rolim de Moura             26.600863     44     14  30.360479   69.0   16.0
# Santa Luzia D'Oeste        26.121212     41     15  30.703297   53.0   18.0
# Seringueiras               24.910714     42     14  30.500000   47.0   20.0
# São Felipe D'Oeste         26.481481     41     17  31.395833   57.0   18.0
# São Francisco do Guaporé   25.660066     41     14  31.638889   54.0   19.0
# São Miguel do Guaporé      25.926346     42     14  32.666667   60.0   19.0
# Teixeirópolis              26.031250     39     16  31.500000   67.0   20.0
# Theobroma                  25.536082     42     15  30.083333   45.0   23.0
# Urupá                      26.688235     43     15  31.008929   48.0   17.0
# Vale do Anari              26.096774     44     14  34.000000   58.0   23.0
# Vale do Paraíso            25.679012     52     14  29.976744   51.0   18.0
# Vilhena                    26.433962     46     14  34.152941   60.0   18.0

# %%
sinasc['fecundidade_alta'] = 0
sinasc.loc[(sinasc['QTDFILVIVO']+sinasc['QTDFILMORT']) > 1.76, 'fecundidade_alta'] = 1
sinasc['fecundidade_alta'].value_counts()
# Out:
# 0    18374
# 1     8654
# Name: fecundidade_alta, dtype: int64
